# %%
# > → büyüktür
# < → kücüktür
# >= → büyük eşittir
# <= → kücük eşittir
# == → eşittir
# != → eşit degildir
# and → ve
# or → veya

# %%
x = 5
y = 4

# %%
x > y
# Out:
# True

# %%
x >=y
# Out:
# True

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
"rumeysa" == "rumeysa"
# Out:
# True

# %%
"rumeysa" != "atlas"
# Out:
# True

# %%
3 > 2 and 4 > 3
# Out:
# True

# %%
3 < 2 and 4 > 3
# Out:
# False

# %%
3 < 2 or 4 > 3
# Out:
# True

# %%
# not → not keyword'ü olumsuzluk belirtir

# %%
not 1 == 1
# Out:
# False

# %%
10 in [10,20,30]
# Out:
# True

# %%
15 in [10,20,30]
# Out:
# False

# %%
10 not in [10,20,30]
# Out:
# False

# %%
15 not in [10,20,30]
# Out:
# True

# %%
10 in {10,20,30}
# Out:
# True

# %%
10 in (10,20,30,40)
# Out:
# True

# %%
ornek_sozluk = {"a":10, "b":20, "c":30}

# %%
10 in ornek_sozluk
# Out:
# False

# %%
"a" in ornek_sozluk
# Out:
# True

# %%
ornek_sozluk.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
"b" in ornek_sozluk.keys()
# Out:
# True

# %%
30 in ornek_sozluk.values()
# Out:
# True

# %%
# if controls, indentation

# %%
sinav_sonucu = 10

# %%
if sinav_sonucu < 40:
    print("sınıfta kaldınız")
    print("bu satırlar sadece sinav_sonucu 40'tan düşükse çalıştırılacak")
# Out:
# sınıfta kaldınız
# bu satırlar sadece sinav_sonucu 40'tan düşükse çalıştırılacak

# %%
sinav_sonucu = 90

# %%
if sinav_sonucu < 40:
    print("sınıfta kaldınız")
    print("bu satırlar sadece sinav_sonucu 40'tan düşükse çalıştırılacak")
elif sinav_sonucu >= 40 and sinav_sonucu <60:
    print("sınav sonucun 40-60 arasında, düşük bir sonuç almışsın")
elif sinav_sonucu >= 60 and sinav_sonucu <80:
    print("sınav sonucun ortalama ve üstünde, iyi denilebilir")
else:
    print("sınav sonucun gayet iyi")
# Out:
# sınav sonucun gayet iyi

# %%
isim = "rumeysa"

# %%
if isim == "rumeysa":
    print("tebrikler isminiz rumeysa")
else:
    print("isminiz rumeysa değilmiş")
# Out:
# tebrikler isminiz rumeysa
