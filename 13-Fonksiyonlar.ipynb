# %%
#method vs function

# %%
isim = "rumeysa"

# %%
isim.capitalize()
# Out:
# 'Rumeysa'

# %%
isim.upper()
# Out:
# 'RUMEYSA'

# %%
isim
# Out:
# 'rumeysa'

# %%
#fonksiyonlar

# %%
def merhaba_fonksiyonlar():
    print("merhaba")
    print("fonksiyonlar")

# %%
merhaba_fonksiyonlar()
# Out:
# merhaba
# fonksiyonlar

# %%
#parameter input

# %%
isim = "rumeysa,songur"
isim.split(",")
# Out:
# ['rumeysa', 'songur']

# %%
def merhaba_isim(input_stringi):
    print("merhaba")
    print(input_stringi)

# %%
merhaba_isim("rumeysa")
# Out:
# merhaba
# rumeysa

# %%
merhaba_isim("zeytin")
# Out:
# merhaba
# zeytin

# %%
def toplama(num1, num2):
    print(num1 + num2)

# %%
toplama(5,10)
# Out:
# 15

# %%
def toplama(num1, num2):
    sonuc = num1 + num2
    print("hesaplama tamamlandı, sonuç:")
    print(sonuc)

# %%
toplama(-10,20)
# Out:
# hesaplama tamamlandı, sonuç:
# 10

# %%
def merhaba_soyisim(soyisim = "songur"):
    print("merhaba", soyisim)

# %%
merhaba_soyisim()
# Out:
# merhaba songur

# %%
merhaba_soyisim("yılmaz")
# Out:
# merhaba yılmaz

# %%
def toplama_ornek(num1 = 0, num2= 0):
    print(num1 + num2)

# %%
toplama_ornek(10,15)
# Out:
# 25

# %%
def uclu_toplama (a,b,c):
    print(a+b+c)

# %%
uclu_toplama(10,20,30)
# Out:
# 60

# %%
# return

# %%
def cikarma(x,y):
    print(x-y)

# %%
cikarma(10,20)
# Out:
# -10

# %%
isim = "atıl"
buyuk_isim = isim.upper()

# %%
isim
# Out:
# 'atıl'

# %%
buyuk_isim
# Out:
# 'ATIL'

# %%
sonuc = cikarma(20,30)
# Out:
# -10

# %%
sonuc

# %%
print(sonuc)
# Out:
# None

# %%
type(sonuc)
# Out:
# NoneType

# %%
def cikarma(x,y):
    sonuc = x-y
    print(sonuc)
    return sonuc

# %%
sonuc = cikarma(10,20)
# Out:
# -10

# %%
sonuc
# Out:
# -10

# %%
type(sonuc)
# Out:
# int

# %%
def anlamsiz_fonksiyon(a,b):
    sonuc = a + b
    return 10

# %%
degisken = anlamsiz_fonksiyon(20,4000)

# %%
degisken
# Out:
# 10

# %%
isim = "rumeysa"

# %%
isim.startswith("r")
# Out:
# True

# %%
isim.startswith("a")
# Out:
# False

# %%
def string_harf_ile_basliyor_mu(metin,harf):
    if metin[0] == harf:
        return True
    else:
        return False

# %%
string_harf_ile_basliyor_mu("rumeysa", "r")
# Out:
# True

# %%
string_harf_ile_basliyor_mu("rumeysa", "a")
# Out:
# False

# %%
def liste_stringlerini_buyuten_fonksiyon(ornek_liste):
    for eleman in ornek_liste:
        print(eleman.upper())

# %%
ornek_liste = ["rumeysa","songur","örnek","liste"]

# %%
liste_stringlerini_buyuten_fonksiyon(ornek_liste)
# Out:
# RUMEYSA
# SONGUR
# ÖRNEK
# LISTE

# %%
sayi_listem=[20,30,40]

# %%
sum(sayi_listem)
# Out:
# 90

# %%
# args, kwargs (arguments, key word arguments)

# %%
def sinirsiz_toplama(*args):
    print(args)

# %%
sinirsiz_toplama(10,20)
# Out:
# (10, 20)

# %%
sinirsiz_toplama(10)
# Out:
# (10,)

# %%
sinirsiz_toplama(10,20,30)
# Out:
# (10, 20, 30)

# %%
def sinirsiz_toplama(*args):
    print(sum(args))

# %%
sinirsiz_toplama(10,20,30,40,50,60)
# Out:
# 210

# %%
def kwargs_ornek(**kwargs):
    print(kwargs)

# %%
kwargs_ornek(elma=100, armut=200, karpuz=300)
# Out:
# {'elma': 100, 'armut': 200, 'karpuz': 300}

# %%
kwargs_ornek(elma=100, armut=200)
# Out:
# {'elma': 100, 'armut': 200}

# %%
def kwargs_ornek(**kwargs):
    print(kwargs.values())

# %%
kwargs_ornek(elma=100, armmut=200, karpuz=300)
# Out:
# dict_values([100, 200, 300])
