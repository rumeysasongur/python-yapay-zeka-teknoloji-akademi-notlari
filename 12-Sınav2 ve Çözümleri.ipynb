# %%
#1)

# %%
x=9
y=11
z=7

# %%
x>y or z<x
# Out:
# True

# %%
#2)

# %%
a=15
b=20

if a>10 and b<30:
    print("A")
elif a>20 or b==20:
    print("B")
else:
    print("C")
# Out:
# A

# %%
#4)

# %%
my_dictionary = {"a":100,"b":"atıl","c":330,"d":"u"}

# %%
"u" in my_dictionary
# Out:
# False

# %%
if "u" in my_dictionary.values():
    print("evet var")
# Out:
# evet var

# %%
#5)

# %%
my_other_dictionary = {"x":20,"y":"a","k":40,"e":"fa"}

# %%
"k" in my_other_dictionary
# Out:
# True

# %%
#6)

# %%
my_numbers = [3,2,5,4,7,6,19,20,32,20,1111,23,44]

# %%
for num in my_numbers:
    if num %2 ==0:
        print(num)
# Out:
# 2
# 4
# 6
# 20
# 32
# 20
# 44

# %%
#7)

# %%
cevreler = []
pi = 3.14
r_list = [1,2,5,8,7,10,9,14]

for r in r_list:
    cevreler.append(2*pi*r)

# %%
cevreler
# Out:
# [6.28,
#  12.56,
#  31.400000000000002,
#  50.24,
#  43.96,
#  62.800000000000004,
#  56.52,
#  87.92]

# %%
#8)

# %%
age_name_list= [("Atıl",30),("Ayse",20),("Ahmet",65),("Mahmut",25)]

# %%
yaslar = []
for isim, yas in age_name_list:
    yaslar.append(yas)

# %%
yaslar
# Out:
# [30, 20, 65, 25]

# %%
#9)

# %%
isimler = ["Atıl","Ahmet","Mehmet","Zeynep","Fatma"]

# %%
from random import randint

# %%
isimler[randint(0,len(isimler)-1)]
# Out:
# 'Mehmet'

# %%
#10)

# %%
number_list = [4,7,12,19,20,8,45,240]

# %%
[num % 2 == 0 for num in number_list]
# Out:
# [True, False, True, False, True, True, False, True]

# %%
4 % 2 ==0
# Out:
# True

# %%
#11)

# %%
from math import sin

# %%
sin(45)
# Out:
# 0.8509035245341184
