# %%
ornek_bool = True

# %%
ornek_bool = False

# %%
type(ornek_bool)
# Out:
# bool

# %%
karakter_canli = True

# %%
3 > 2
# Out:
# True

# %%
isim = "rumeysa"

# %%
isim2 = "rumeysa"

# %%
isim == isim2
# Out:
# True

# %%
isim != isim2
# Out:
# False

# %%
isim.startswith("r")
# Out:
# True

# %%
isim.startswith("a")
# Out:
# False
