# %%
# list, dict, set, tuple

# %%
numara_listesi = [10, 20, 30, 40, 50, 60, 70, 80]

# %%
numara_listesi [0]
# Out:
# 10

# %%
numara_listesi[1]
# Out:
# 20

# %%
numara_listesi[-1]
# Out:
# 80

# %%
len(numara_listesi)
# Out:
# 8

# %%
type(numara_listesi)
# Out:
# list

# %%
isim = "rumeysa"

# %%
isim[0]
# Out:
# 'r'

# %%
# isim[0] = "b" → bu çalışmaz

# %%
numara_listesi
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
numara_listesi[0] = 100

# %%
numara_listesi
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80]

# %%
# [starting_index : stopping_index : step_size]

# %%
numara_listesi[4::]
# Out:
# [50, 60, 70, 80]

# %%
numara_listesi[:5:]
# Out:
# [100, 20, 30, 40, 50]

# %%
numara_listesi[::2]
# Out:
# [100, 30, 50, 70]

# %%
numara_listesi[1:6:2]
# Out:
# [20, 40, 60]

# %%
numara_listesi
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80]

# %%
numara_listesi.append(90)

# %%
numara_listesi
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
yeni_liste = numara_listesi.copy()

# %%
yeni_liste
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
numara_listesi
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
numara_listesi.count(20)
# Out:
# 1

# %%
numara_listesi.count(25)
# Out:
# 0

# %%
liste1 = [10,20,30]
liste2 = [30,40,50]

# %%
liste1.extend(liste2)

# %%
liste1
# Out:
# [10, 20, 30, 30, 40, 50]

# %%
numara_listesi
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
numara_listesi.index(30)
# Out:
# 2

# %%
help(numara_listesi.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
numara_listesi.insert(2, 250)

# %%
numara_listesi
# Out:
# [100, 20, 250, 30, 40, 50, 60, 70, 80, 90]

# %%
numara_listesi.pop()
# Out:
# 90

# %%
numara_listesi
# Out:
# [100, 20, 250, 30, 40, 50, 60, 70, 80]

# %%
numara_listesi.remove(250)

# %%
numara_listesi
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80]

# %%
numara_listesi.reverse()

# %%
numara_listesi
# Out:
# [80, 70, 60, 50, 40, 30, 20, 100]

# %%
numara_listesi.sort()

# %%
numara_listesi
# Out:
# [20, 30, 40, 50, 60, 70, 80, 100]

# %%
liste1 = [10, 20, 30]
liste2 = [20, 30, 40]

# %%
liste1 + liste2
# Out:
# [10, 20, 30, 20, 30, 40]

# %%
liste_toplamı = liste1 + liste2

# %%
liste_toplamı
# Out:
# [10, 20, 30, 20, 30, 40]

# %%
liste1 * 3
# Out:
# [10, 20, 30, 10, 20, 30, 10, 20, 30]

# %%
string_listesi = ["rumeysa", "songur", "faik", "ekim", "panda", "mars"]

# %%
len(string_listesi)
# Out:
# 6

# %%
string_listesi[-1] = "nazlı"

# %%
string_listesi
# Out:
# ['rumeysa', 'songur', 'faik', 'ekim', 'panda', 'nazlı']

# %%
string_listesi.sort()

# %%
string_listesi
# Out:
# ['ekim', 'faik', 'nazlı', 'panda', 'rumeysa', 'songur']

# %%
karışık_liste = [100, 250, 570, "rumeysa", "faik", "atlas", "pars"]

# %%
karışık_liste[0] * 100
# Out:
# 10000

# %%
karışık_liste[-1] * 2
# Out:
# 'parspars'

# %%
len(karışık_liste)
# Out:
# 7

# %%
#nested_list

# %%
ornek_liste = [100, 200, "rumeysa", [10, 20, 30], 5.25]

# %%
len(ornek_liste)
# Out:
# 5

# %%
ornek_liste[3]
# Out:
# [10, 20, 30]

# %%
ic_liste = ornek_liste[3]

# %%
ic_liste[-1]
# Out:
# 30

# %%
ornek_liste[3][-1]
# Out:
# 30

# %%
matrix_listesi = [[10,20,30],[40,50,60],[70,80,90]]

# %%
len(matrix_listesi)
# Out:
# 3

# %%
matrix_listesi [0][1]
# Out:
# 20

# %%
matrix_listesi[2][0]
# Out:
# 70
