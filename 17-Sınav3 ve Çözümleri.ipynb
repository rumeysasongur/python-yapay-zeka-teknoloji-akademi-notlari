# %%
#1)

# %%
def cikarma(a,b):
    print(a-b)

# %%
x = cikarma(3,4)
# Out:
# -1

# %%
print(x)
# Out:
# None

# %%
#2)

# %%
def ussunu_al(x=4, y=3):
    print(x ** y)

# %%
ussunu_al(2,4)
# Out:
# 16

# %%
ussunu_al()        #3)
# Out:
# 64

# %%
#4)

# %%
def loop_yap(*args):
    for eleman in args:
        print (eleman/2)

# %%
loop_yap(3,2,1,5,3,4)
# Out:
# 1.5
# 1.0
# 0.5
# 2.5
# 1.5
# 2.0

# %%
#5)

# %%
def benim_fonksiyonum(num):
    return num ** 3

# %%
benim_listem = [5,7,8,10,12]

# %%
list(map(benim_fonksiyonum,benim_listem))
# Out:
# [125, 343, 512, 1000, 1728]

# %%
#6)

# %%
barkod_dizisi= ["ABC231", "SA3123XYZ", "XYZA1230", "QREABC1KJ", "X112QGL"]

# %%
list(filter(lambda string : "ABC" in string,barkod_dizisi))
# Out:
# ['ABC231', 'QREABC1KJ']

# %%
yeni_liste = []
for barkod in barkod_dizisi:
    if "ABC" in barkod:
        yeni_liste.append(barkod)

# %%
yeni_liste
# Out:
# ['ABC231', 'QREABC1KJ']

# %%
#7)

# %%
degisken = "Atil Samancioglu"

def ornek_fonksiyon():
    degisken = "Atil"

    def diger_fonksiyon():
        print(degisken)

    diger_fonksiyon()

# %%
ornek_fonksiyon()
# Out:
# Atil

# %%
#8)

# %%
class Kopek():
    def __init__(self, isim, yas=3):
        self.isim = isim
        self.yas = yas

    def yasi_carp(self):
        return self.yas * 4

# %%
kopek = Kopek("Barley")

# %%
kopek.yasi_carp()
# Out:
# 12

# %%
#9)

# %%
class Ogrenci():

    def __init__(self, isim,sinav_notu):
        self.isim = isim
        self.__sinav_notu = sinav_notu

    def notu_goster(self):
        print(f"{self.isim} sınav notu: {self.__sinav_notu}")

# %%
ogrenci = Ogrenci("Atıl",75)

# %%
ogrenci.__sinav_notu = 95

# %%
ogrenci.notu_goster()
# Out:
# Atıl sınav notu: 75

# %%
#10) cevap: abstraction (soyutlama)
