# %%
# str - string → metinler

# %%
isim = "rumeysa songür"

# %%
type(isim)
# Out:
# str

# %%
isim = "rumeysa"

# %%
soyisim = "songür"

# %%
isim.capitalize()
# Out:
# 'Rumeysa'

# %%
isim.upper()
# Out:
# 'RUMEYSA'

# %%
x = 10

# %%
type(x)
# Out:
# int

# %%
isim + soyisim
# Out:
# 'rumeysasongür'

# %%
tam_isim = isim + " " + soyisim

# %%
tam_isim
# Out:
# 'rumeysa songür'

# %%
isim * 5
# Out:
# 'rumeysarumeysarumeysarumeysarumeysa'

# %%
isim.upper()
# Out:
# 'RUMEYSA'

# %%
help(isim.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
isim.count("a")
# Out:
# 1

# %%
isim.count("ğ")
# Out:
# 0

# %%
isim.islower()
# Out:
# True

# %%
isim
# Out:
# 'rumeysa'

# %%
isim.upper()
# Out:
# 'RUMEYSA'

# %%
isim_buyuk_harf = isim.upper()

# %%
isim
# Out:
# 'rumeysa'

# %%
isim_buyuk_harf
# Out:
# 'RUMEYSA'

# %%
help(isim.endswith)
# Out:
# Help on built-in function endswith:
#
# endswith(suffix[, start[, end]], /) method of builtins.str instance
#     Return True if the string ends with the specified suffix, False otherwise.
#
#     suffix
#       A string or a tuple of strings to try.
#     start
#       Optional start position. Default: start of the string.
#     end
#       Optional stop position. Default: end of the string.

# %%
isim.endswith("sa")
# Out:
# True

# %%
isim.endswith("ğ")
# Out:
# False

# %%
#index

# %%
isim = "rumeysa songür"

# %%
isim[0]
# Out:
# 'r'

# %%
len(isim) - 1
# Out:
# 13

# %%
isim[len(isim) -1]
# Out:
# 'r'

# %%
isim = "rumeysa"

# %%
isim[len(isim) -1]
# Out:
# 'a'

# %%
isim[-1]
# Out:
# 'a'

# %%
isim[-2]
# Out:
# 's'

# %%
isim = "rumeysa songür"

# %%
isim[0]
# Out:
# 'r'

# %%
isim[-1]
# Out:
# 'r'

# %%
isim[0] + isim[-1]
# Out:
# 'rr'

# %%
#slicing (dilimleme)

# %%
barkod = "ABCDEF123456"

# %%
# [starting_index:stopping_index:step_size]

# %%
barkod[::]
# Out:
# 'ABCDEF123456'

# %%
barkod[4::]
# Out:
# 'EF123456'

# %%
barkod[:6:]
# Out:
# 'ABCDEF'

# %%
barkod[2:7:]
# Out:
# 'CDEF1'

# %%
barkod[::2]
# Out:
# 'ACE135'

# %%
barkod[2:8:2]
# Out:
# 'CE1'

# %%
# step size → - verirsek tersten başlar.

# %%
barkod
# Out:
# 'ABCDEF123456'

# %%
barkod[::-1]
# Out:
# '654321FEDCBA'

# %%
isim
# Out:
# 'rumeysa songür'

# %%
isim.find("e")
# Out:
# 3

# %%
isim.index("e")
# Out:
# 3

# %%
isim.index("sa")
# Out:
# 5

# %%
isim.find("ş")
# Out:
# -1

# %%
isim.index("u")
# Out:
# 1

# %%
isimler = "rumeysa,atıl"

# %%
isim.split()
# Out:
# ['rumeysa', 'songür']

# %%
isimler.split()
# Out:
# ['rumeysa,atıl']

# %%
type(isim.split())
# Out:
# list
